# %% [markdown]
# <a href="https://colab.research.google.com/github/a2r4vind/Machine-Learning-Models/blob/main/Simple_One_Hidden_layer_NN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network model with one hidden layer for classification problem

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# Create a simple dataset

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

# %% [markdown]
# Build a feedforward NN

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, activation='sigmoid', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Train the model

# %%
model.fit(X, y, epochs=1000, verbose=0)

# %% [markdown]
# Evaluate the model

# %%
loss, accuracy = model.evaluate(X, y)
print('Loss: ',loss)
print('Accuracy: ', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.5000 - loss: 0.6919
# Loss:  0.6919240355491638
# Accuracy:  0.5

# %% [markdown]
# Make predictions

# %%
predictions = model.predict(X)
print('Predictions:')
for i in range(len(X)):
  print(f'Input : {X[i]}, Prediction: {predictions[i][0]:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Predictions:
# Input : [0 0], Prediction: 0.5100
# Input : [0 1], Prediction: 0.4930
# Input : [1 0], Prediction: 0.5102
# Input : [1 1], Prediction: 0.4903
