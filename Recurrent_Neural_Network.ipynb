# %% [markdown]
# <a href="https://colab.research.google.com/github/a2r4vind/Machine-Learning-Models/blob/main/Recurrent_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementing Recurrent Neural Network (RNN)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %% [markdown]
# # Generate synthetic data

# %%
np.random.seed(42)
sequence_length = 10
num_samples = 1000
input_dim = 1

# %%
X = np.random.random((num_samples, sequence_length, input_dim))
y = np.sum(X, axis=1)

# %% [markdown]
# Split the Data into training and testing sets

# %%
split_ratio = 0.8
split_index = int(split_ratio * num_samples)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %% [markdown]
# Build the RNN model

# %%
model = Sequential()
model.add(SimpleRNN(10, input_shape=(sequence_length, input_dim), activation='relu'))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# Train the model

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 20.1584 - val_loss: 15.8766
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2807 - val_loss: 3.9220
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8509 - val_loss: 0.3900
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2581 - val_loss: 0.2034
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1782 - val_loss: 0.1918
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1783 - val_loss: 0.1810
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1647 - val_loss: 0.1701
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1556 - val_loss: 0.1525
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1401 - val_loss: 0.1379
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1338 - val_loss: 0.1201

# %% [markdown]
# Evaluate the model on the test data

# %%
test_loss = model.evaluate(X_test, y_test)
print("Test Loss: ", test_loss)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1184
# Test Loss:  0.12011773884296417

# %% [markdown]
# Making the predictions using the trained model

# %%
predictions = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
for i in range(5):
  print(f"Predicted Value: {predictions[i][0]}, Actual Value: {y_test[i]}")
# Out:
# Predicted Value: 5.23471212387085, Actual Value: [5.10520034]
# Predicted Value: 5.867735385894775, Actual Value: [6.03618101]
# Predicted Value: 5.379201889038086, Actual Value: [5.5720844]
# Predicted Value: 4.932796001434326, Actual Value: [4.68995643]
# Predicted Value: 4.841406345367432, Actual Value: [4.29333816]
